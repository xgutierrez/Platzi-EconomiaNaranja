# %% [markdown]
# # Análisis de Datos

# %% [markdown]
# El Book tiene como objetivo hacer una exploración de datos, para esto se lo realiza con una archivo de economía naranja

# %%
import pandas as pd

# %% [markdown]
# ## 1. Estructura, tipos de datos y sintaxis

# %% [markdown]
# ### Carga de información

# %% [markdown]
# * Carga del archivo mtcars

# %%
mtcars = pd.read_csv('mtcars.csv')
mtcars.head(5)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %% [markdown]
# * Carga del archivo de Economía Naranja

# %%
orangeec = pd.read_csv('orangeec.csv')
orangeec.head()
# Out:
#      Country  GDP PC  GDP US bill  GDP Growth %  Services % GDP  \
# 0  Argentina   20900        637.7           2.9            60.9
# 1     Belize    8300       1854.0           0.8            62.2
# 2    Bolivia    7500         37.1           4.2            50.0
# 3     Brazil   15600    2055000.0           1.0            72.8
# 4      Chile   24500        277.0           1.5            64.3
#
#    Creat Ind % GDP  Inflation  Unemployment  % pop below poverty line  \
# 0              3.8       25.7           8.1                      25.7
# 1              NaN        1.1          10.1                      41.0
# 2              NaN        2.8           4.0                      38.6
# 3              2.6        3.4          11.8                       4.2
# 4              2.2        2.2           7.0                      14.4
#
#    Internet penetration % population  Median age  % pop 25-54  \
# 0                               93.1        31.7        39.38
# ...

# %% [markdown]
# ### Tipo de datos en el Dataset

# %% [markdown]
# Vamos a entender que tipo de datos tiene nuestro Dataset

# %% [markdown]
# * Datos de mtcars

# %%
mtcars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
# model    32 non-null object
# mpg      32 non-null float64
# cyl      32 non-null int64
# disp     32 non-null float64
# hp       32 non-null int64
# drat     32 non-null float64
# wt       32 non-null float64
# qsec     32 non-null float64
# vs       32 non-null int64
# am       32 non-null int64
# gear     32 non-null int64
# carb     32 non-null int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %% [markdown]
# * Datos de Economía naranja

# %%
orangeec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 13 columns):
# Country                              17 non-null object
# GDP PC                               17 non-null int64
# GDP US bill                          17 non-null float64
# GDP Growth %                         17 non-null float64
# Services % GDP                       17 non-null float64
# Creat Ind % GDP                      11 non-null float64
# Inflation                            17 non-null float64
# Unemployment                         17 non-null float64
# % pop below poverty line             17 non-null float64
# Internet penetration % population    17 non-null float64
# Median age                           17 non-null float64
# % pop 25-54                          17 non-null float64
# Education invest % GDP               17 non-null float64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 1.8+ KB

# %% [markdown]
# ### Sumary de datos

# %% [markdown]
# Entendiendo la estadística de nuestros datos

# %%
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
orangeec.describe()
# Out:
#              GDP PC   GDP US bill  GDP Growth %  Services % GDP  \
# count     17.000000  1.700000e+01     17.000000       17.000000
# mean   14052.941176  1.886930e+05      2.958824       62.635294
# std     6624.303515  5.555371e+05      1.370246        8.311885
# min     5600.000000  1.370000e+01      0.800000       50.000000
# 25%     8300.000000  3.710000e+01      2.000000       56.900000
# 50%    13300.000000  7.570000e+01      2.800000       62.200000
# 75%    19900.000000  3.092000e+02      4.200000       64.900000
# max    25400.000000  2.055000e+06      5.400000       82.000000
#
#        Creat Ind % GDP  Inflation  Unemployment  % pop below poverty line  \
# count        11.000000  17.000000     17.000000                 17.000000
# mean          3.290909   4.364706      6.794118                 27.652941
# std           2.007712   5.756077      2.489345                 13.411055
# min           1.000000   0.400000      2.300000                  4.200000
# ...

# %% [markdown]
# ### Transformación de datos
#
# * Vamos a realizar una conversión de datos del dataset mtcars el campo de wt (peso), que esta en libras

# %%
mtcars['wt'] = (mtcars['wt'] * 1000)/2
mtcars
# Out:
#                   model   mpg  cyl   disp   hp  drat      wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  1310.0  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  1437.5  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  1160.0  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  1607.5  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  1720.0  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  1730.0  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  1785.0  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  1595.0  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  1575.0  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  1720.0  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  1720.0  18.90   1   0
# ...
